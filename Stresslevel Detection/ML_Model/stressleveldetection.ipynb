# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
import tensorflow as tf
import tensorflow.keras as k
import time
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  885.157845  853.763730  140.972741  15.554505  15.553371    9.063146
# 1  939.425371  948.357865   81.317742  12.964439  12.964195    6.272369
# 2  898.186047  907.006860   84.497236  16.305279  16.305274    5.182201
# 3  881.757864  893.460030   90.370537  15.720468  15.720068    5.748591
# 4  809.625331  811.184865   62.766242  19.213819  19.213657    3.266724
#
#           HR      pNN25     pNN50        SD1  ...         HF    HF_PCT  \
# 0  69.499952  11.133333  0.533333  11.001565  ...  15.522602  0.421047
# 1  64.363150   5.600000  0.000000   9.170129  ...   2.108525  0.070133
# 2  67.450066  13.066667  0.200000  11.533417  ...  13.769729  0.512671
# 3  68.809562  11.800000  0.133333  11.119476  ...  18.181913  0.529387
# 4  74.565728  20.200000  0.200000  13.590641  ...  48.215822  1.839473
#
#       HF_NU           TP       LF_HF     HF_LF    sampen    higuci  datasetId  \
# 0  1.514737  3686.666157   65.018055  0.015380  2.139754  1.163485          2
# 1  0.304603  3006.487251  327.296635  0.003055  2.174499  1.084711          2
# 2  1.049528  2685.879461   94.280910  0.010607  2.135350  1.176315          2
# 3  1.775294  3434.520980   55.328701  0.018074  2.178341  1.179688          2
# 4  3.279993  2621.175204   29.487873  0.033912  2.221121  1.249612          2
#
#    condition
# 0          0
# 1          1
# 2          1
# 3          0
# 4          0
#
# [5 rows x 36 columns]

# %%
label = ['condition']
features = ['MEAN_RR','RMSSD','pNN25','pNN50','LF','HF','LF_HF']

# %%
scaler = StandardScaler()
scaler.fit(df[features])
df[features] = scaler.transform(df[features])

# %%
X = df[features].values
y = df[label].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=40)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (258502, 7) (258502, 1) (110787, 7) (110787, 1)

# %%
y_train = k.utils.to_categorical(y_train)
y_test = k.utils.to_categorical(y_test)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(50,activation='relu',kernel_initializer='he_normal',input_shape=(X_train.shape[1],)))
model.add(Dense(20,activation='relu',kernel_initializer='he_normal'))
model.add(Dense(10,activation='relu',kernel_initializer='he_normal'))
model.add(Dense(3,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs = 50,batch_size=1024,verbose=1)
# Out:
# Epoch 1/50
# 253/253 [==============================] - 1s 3ms/step - loss: 0.8415 - accuracy: 0.6222 - val_loss: 0.7212 - val_accuracy: 0.6856
# Epoch 2/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.6475 - accuracy: 0.7201 - val_loss: 0.5882 - val_accuracy: 0.7497
# Epoch 3/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.5402 - accuracy: 0.7761 - val_loss: 0.5017 - val_accuracy: 0.7954
# Epoch 4/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.4631 - accuracy: 0.8136 - val_loss: 0.4328 - val_accuracy: 0.8285
# Epoch 5/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.4047 - accuracy: 0.8428 - val_loss: 0.3831 - val_accuracy: 0.8552
# Epoch 6/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.3620 - accuracy: 0.8637 - val_loss: 0.3448 - val_accuracy: 0.8716
# Epoch 7/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.3303 - accuracy: 0.8765 - val_loss: 0.3186 - val_accuracy: 0.8815
# Epoch 8/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.3052 - accuracy: 0.8867 - val_loss: 0.2972 - val_accuracy: 0.8908
# Epoch 9/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.2851 - accuracy: 0.8947 - val_loss: 0.2801 - val_accuracy: 0.8953
# Epoch 10/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.2678 - accuracy: 0.9017 - val_loss: 0.2658 - val_accuracy: 0.9007
# Epoch 11/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.2534 - accuracy: 0.9071 - val_loss: 0.2499 - val_accuracy: 0.9073
# Epoch 12/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.2412 - accuracy: 0.9118 - val_loss: 0.2351 - val_accuracy: 0.9140
# Epoch 13/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.2300 - accuracy: 0.9162 - val_loss: 0.2275 - val_accuracy: 0.9163
# Epoch 14/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.2214 - accuracy: 0.9196 - val_loss: 0.2173 - val_accuracy: 0.9204
# Epoch 15/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.2128 - accuracy: 0.9227 - val_loss: 0.2122 - val_accuracy: 0.9211
# Epoch 16/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.2060 - accuracy: 0.9247 - val_loss: 0.2044 - val_accuracy: 0.9241
# Epoch 17/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.2002 - accuracy: 0.9263 - val_loss: 0.1998 - val_accuracy: 0.9268
# Epoch 18/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1938 - accuracy: 0.9285 - val_loss: 0.1948 - val_accuracy: 0.9264
# Epoch 19/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1895 - accuracy: 0.9295 - val_loss: 0.1947 - val_accuracy: 0.9265
# Epoch 20/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1847 - accuracy: 0.9314 - val_loss: 0.1850 - val_accuracy: 0.9327
# Epoch 21/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1798 - accuracy: 0.9337 - val_loss: 0.1789 - val_accuracy: 0.9340
# Epoch 22/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1754 - accuracy: 0.9348 - val_loss: 0.1776 - val_accuracy: 0.9332
# Epoch 23/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1728 - accuracy: 0.9357 - val_loss: 0.1749 - val_accuracy: 0.9344
# Epoch 24/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1684 - accuracy: 0.9368 - val_loss: 0.1688 - val_accuracy: 0.9370
# Epoch 25/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1648 - accuracy: 0.9384 - val_loss: 0.1673 - val_accuracy: 0.9359
# Epoch 26/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1618 - accuracy: 0.9391 - val_loss: 0.1624 - val_accuracy: 0.9374
# Epoch 27/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1585 - accuracy: 0.9404 - val_loss: 0.1584 - val_accuracy: 0.9390
# Epoch 28/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1562 - accuracy: 0.9408 - val_loss: 0.1606 - val_accuracy: 0.9377
# Epoch 29/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1534 - accuracy: 0.9419 - val_loss: 0.1529 - val_accuracy: 0.9410
# Epoch 30/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1517 - accuracy: 0.9424 - val_loss: 0.1533 - val_accuracy: 0.9408
# Epoch 31/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1484 - accuracy: 0.9438 - val_loss: 0.1555 - val_accuracy: 0.9398
# Epoch 32/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1461 - accuracy: 0.9439 - val_loss: 0.1486 - val_accuracy: 0.9412
# Epoch 33/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1441 - accuracy: 0.9450 - val_loss: 0.1434 - val_accuracy: 0.9457
# Epoch 34/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1420 - accuracy: 0.9460 - val_loss: 0.1430 - val_accuracy: 0.9437
# Epoch 35/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1416 - accuracy: 0.9460 - val_loss: 0.1460 - val_accuracy: 0.9441
# Epoch 36/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1370 - accuracy: 0.9480 - val_loss: 0.1375 - val_accuracy: 0.9470
# Epoch 37/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1359 - accuracy: 0.9481 - val_loss: 0.1432 - val_accuracy: 0.9450
# Epoch 38/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1345 - accuracy: 0.9488 - val_loss: 0.1344 - val_accuracy: 0.9477
# Epoch 39/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1323 - accuracy: 0.9498 - val_loss: 0.1322 - val_accuracy: 0.9494
# Epoch 40/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1313 - accuracy: 0.9501 - val_loss: 0.1350 - val_accuracy: 0.9475
# Epoch 41/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1297 - accuracy: 0.9505 - val_loss: 0.1299 - val_accuracy: 0.9493
# Epoch 42/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1277 - accuracy: 0.9517 - val_loss: 0.1321 - val_accuracy: 0.9487
# Epoch 43/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1258 - accuracy: 0.9525 - val_loss: 0.1281 - val_accuracy: 0.9505
# Epoch 44/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1248 - accuracy: 0.9524 - val_loss: 0.1235 - val_accuracy: 0.9526
# Epoch 45/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1223 - accuracy: 0.9539 - val_loss: 0.1223 - val_accuracy: 0.9521
# Epoch 46/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1221 - accuracy: 0.9539 - val_loss: 0.1228 - val_accuracy: 0.9532
# Epoch 47/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1203 - accuracy: 0.9546 - val_loss: 0.1218 - val_accuracy: 0.9529
# Epoch 48/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1191 - accuracy: 0.9548 - val_loss: 0.1192 - val_accuracy: 0.9538
# Epoch 49/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1188 - accuracy: 0.9553 - val_loss: 0.1194 - val_accuracy: 0.9546
# Epoch 50/50
# 253/253 [==============================] - 1s 2ms/step - loss: 0.1175 - accuracy: 0.9554 - val_loss: 0.1149 - val_accuracy: 0.9570

# %%
pd.DataFrame(history.history).plot(figsize=(10,7))
# Out:
# <Axes: >

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test[features] = scaler.transform(df_test[features])
df_test[features].head()
# Out:
#     MEAN_RR     RMSSD     pNN25     pNN50        LF        HF     LF_HF
# 0 -1.001159 -0.634891 -0.598837 -0.874583 -0.575814  0.602911 -0.295775
# 1 -0.024971  1.048686  1.361573 -0.672601  1.080403 -0.280746 -0.157544
# 2  0.897836  1.544671  1.743894  0.943254  1.965161 -0.511482  0.037412
# 3 -0.175046 -0.777935 -0.623241 -0.335965 -0.767443 -0.477196 -0.241658
# 4 -0.721825 -0.393071 -0.476820 -0.201310 -0.735541 -0.089133 -0.280126

# %%
X = df_test[features].values
y = df_test[label].values

# %%
y = k.utils.to_categorical(y)

# %%
loss,acc = model.evaluate(X,y,verbose=1)
# Out:
# 1283/1283 [==============================] - 1s 930us/step - loss: 0.1132 - accuracy: 0.9581

# %%
data = pd.read_csv('test.csv')

# %%
t = scaler.transform(data[features].iloc[5545].values.reshape(1,-1))
print(t)
# Out:
# [[-0.7699341   0.25391942  0.11699709  0.60661783  0.54497884  0.50787441
#   -0.26537627]]
# C:\Users\akhil\anaconda3\envs\main\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
y_pred = model.predict(t)
# Out:
# 1/1 [==============================] - 0s 82ms/step

# %%
print(np.argmax(y_pred[0]))
print(data[label].iloc[5545])
# Out:
# 0
# condition    0
# Name: 5545, dtype: int64

# %%
import joblib

joblib.dump(scaler,'scaler.joblib',compress=9)
model.save('tfmodel.h5')

# %%
df = pd.read_csv('train.csv')
